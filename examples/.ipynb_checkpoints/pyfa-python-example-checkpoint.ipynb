# %%
import pyfa_tool as pyfa
print(pyfa.__version__)
# Out:
# 0.0.2a

# %% [markdown]
# ## The different pyfa classes
# There are 3 classes in pyfa that you can use and create. Each of these classes has a specific application, which must be used accordingly by the user.
# * The **FaFile**class: For quick and fast inspection of what can be found in an FA file
# * The **FaDataset** class: Holds data and methods to work with a xarray.Dataset equivalent of the FA file.
# * The **FaCollection** class: Holds methods on how to combine multiple FaDatasets.
#
# In this example we will introduce the most commen functionallities of these classes

# %% [markdown]
# ## FaFile : Fast overview of the Fa content
# We start by defining the paths to the FA files we want to use in pyfa. We use the demo FA file for this example.
# Then we create a FaFile object for the demo FA file.

# %%
fa_filepath = pyfa.demo_fa
print(fa_filepath)

#Now we create a FaFile object
fafile = pyfa.FaFile(fafile=fa_filepath)
print(fafile)
# Out:
# /home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHABOF+0732
# FA-file at /home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHABOF+0732

# %% [markdown]
# The FaFile holds only the meta-data and fieldnames from the FA file. You can get them using these getters, which can be handy if you want a deep inspection.

# %%
fieldnames_dataframe = fafile.get_fieldnames()
print(fieldnames_dataframe.head()) #Print only the first lines

metadata = fafile.get_metadata()
print(metadata) #The metadata is stored in a dictionary
# Out:
#                name  offset  length  spectral  nbits  index  sptrunc  sppow
# 0   PROFTEMPERATURE   77128  145888     False   16.0      8      NaN    NaN
# 1    PROFRESERV.EAU  223016  145888     False   16.0      9      NaN    NaN
# 2  PROFRESERV.GLACE  368904  145888     False   16.0     10      NaN    NaN
# 3  SURFRESERV.NEIGE  514792  145888     False   16.0     11      NaN    NaN
# 4  SURFALBEDO NEIGE  660680  145888     False   16.0     12      NaN    NaN
# {'basedate': ['2022-12-01'], 'validate': ['2022-12-31 12:00:00'], 'leadtime': ['732'], 'timestep': ['450'], 'origin': ['/home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHABOF+0732'], 'projection': ['lcc'], 'lon_0': [9.9], 'lat_1': [49], 'lat_2': [49], 'proj_R': [6371229], 'nx': [251], 'ny': [251], 'dx': [25000], 'dy': [25000], 'ex': [19], 'ey': [19], 'center_lon': [9.9], 'center_lat': [49], 'nfields': [410], 'filepath': ['/home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHABOF+0732'], 'ndlux': [251], 'ndgux': [251], 'nsmax': [134], 'nlev': [46], 'refpressure': [101325], 'A_list': [0, 0.0001, 0.0003, 0.0007, 0.0013, 0.0023, 0.0045, 0.0051, 0.0073, 0.0092, 0.0108, 0.0123, 0.0135, 0.0145, 0.0154, 0.016, 0.0165, 0.0168, 0.0169, 0.0169, 0.0168, 0.0165, 0.0161, 0.0157, 0.0151, 0.0144, 0.0137, 0.0129, 0.0121, 0.0112, 0.0103, 0.0094, 0.0085, 0.0075, 0.0066, 0.0057, 0.0048, 0.004, 0.0032, 0.0025, 0.0018, 0.0012, 0.0008, 0.0004, 0.0001, 0, 0], 'B_list': [0, 0, 0, 0, 0, 0, 0, 0.0035, 0.0102, 0.0201, 0.0328, 0.0484, 0.0666, 0.0871, 0.11, 0.1349, 0.1617, 0.1903, 0.2204, 0.2519, 0.2846, 0.3184, 0.3531, 0.3884, 0.4243, 0.4606, 0.497, 0.5335, 0.5698, 0.6057, 0.6412, 0.676, 0.7099, 0.7429, 0.7746, 0.805, 0.8338, 0.8609, 0.8862, 0.9094, 0.9304, 0.949, 0.965, 0.9783, 0.9887, 0.996, 1]}

# %% [markdown]
# An general, a formatted description of what is in the FA file is handyer. The describe() prints out an overview of the FA content:

# %%
fafile.describe()
# Out:
# ### File format : FA
#
# ## File name: ['/home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHABOF+0732']
# ## File path: ['/home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHABOF+0732']
#
# #################
# ##   VALIDITY  ##
# #################
#
# Validity               : 2022-12-31 12:00:00
# Basedate               : 2022-12-01 00:00:00
# Leadtime               : 30 days, 12:00:00
#
# Timestep               : 0:07:30
# N time iterations      : 5856
#
#
# #######################
# ## HORIZONTAL GEOMETRY
# #######################
#
# Points of C+I in X      : 251
# Points of C+I in Y      : 251
#
# Kind of projection      : lcc
# Reference lat (ELAT0)   : 49
# Reference lon (ELON0)   : 9.9
# Center lat              : 49
# Center lon              : 9.9
#
# Resolution in X (m)     : 25000
# Resolution in Y (m)     : 25000
#
#
# #######################
# ## Vertical GEOMETRY
# #######################
# N levels                : 46
# Ref pressure            : 101325
#
# Vert coords A           :
# [0, 0.0001, 0.0003, 0.0007, 0.0013, 0.0023, 0.0045, 0.0051, 0.0073, 0.0092, 0.0108, 0.0123, 0.0135, 0.0145, 0.0154, 0.016, 0.0165, 0.0168, 0.0169, 0.0169, 0.0168, 0.0165, 0.0161, 0.0157, 0.0151, 0.0144, 0.0137, 0.0129, 0.0121, 0.0112, 0.0103, 0.0094, 0.0085, 0.0075, 0.0066, 0.0057, 0.0048, 0.004, 0.0032, 0.0025, 0.0018, 0.0012, 0.0008, 0.0004, 0.0001, 0, 0]
#
# Vert coords B           :
# [0, 0, 0, 0, 0, 0, 0, 0.0035, 0.0102, 0.0201, 0.0328, 0.0484, 0.0666, 0.0871, 0.11, 0.1349, 0.1617, 0.1903, 0.2204, 0.2519, 0.2846, 0.3184, 0.3531, 0.3884, 0.4243, 0.4606, 0.497, 0.5335, 0.5698, 0.6057, 0.6412, 0.676, 0.7099, 0.7429, 0.7746, 0.805, 0.8338, 0.8609, 0.8862, 0.9094, 0.9304, 0.949, 0.965, 0.9783, 0.9887, 0.996, 1]
#
#
#
# #######################
# ## FIELDS
# #######################
#
# Number of fields        : [410]
#
#
# ########## 2D #########
#
# name               index   spectral  nbits
# ------------------------------------------
# PROFTEMPERATURE     8       False   16.0
# PROFRESERV.EAU      9       False   16.0
# PROFRESERV.GLACE    10      False   16.0
# SURFRESERV.NEIGE    11      False   16.0
# SURFALBEDO NEIGE    12      False   16.0
# SURFDENSIT.NEIGE    13      False   16.0
# SURFALBEDO HISTO    14      False   16.0
# SURFTEMPERATURE     15      False   16.0
# SURFRESERV.EAU      16      False   16.0
# SURFRESERV.INTER    17      False   16.0
# SURFRESERV.GLACE    18      False   16.0
# SURFZ0.FOIS.G       19      False   nan
# SURFALBEDO          20      False   16.0
# SURFEMISSIVITE      21      False   16.0
# SURFET.GEOPOTENT    22      False   16.0
# SURFIND.TERREMER    23      False   16.0
# SURFPROP.VEGETAT    24      False   16.0
# SURFVAR.GEOP.ANI    25      False   16.0
# SURFVAR.GEOP.DIR    26      False   16.0
# SURFPROP.ARGILE     27      False   16.0
# SURFPROP.SABLE      28      False   16.0
# SURFEPAIS.SOL       29      False   16.0
# SURFIND.VEG.DOMI    30      False   16.0
# SURFRESI.STO.MIN    31      False   16.0
# SURFIND.FOLIAIRE    32      False   16.0
# SURFRES.EVAPOTRA    33      False   16.0
# SURFGZ0.THERM       34      False   nan
# SURFALBEDO.SOLNU    35      False   16.0
# SURFALBEDO.VEG      36      False   16.0
# SURFAEROS.SEA       37      False   16.0
# SURFAEROS.LAND      38      False   16.0
# SURFAEROS.SOOT      39      False   16.0
# SURFAEROS.DESERT    40      False   16.0
# SURFA.OF.OZONE      41      False   16.0
# SURFB.OF.OZONE      42      False   16.0
# SURFC.OF.OZONE      43      False   16.0
# SUNSHI. DURATION    44      False   16.0
# SURFNEBUL.TOTALE    183     False   16.0
# SURFNEBUL.CONVEC    184     False   16.0
# SURFNEBUL.HAUTE     185     False   16.0
# SURFNEBUL.MOYENN    186     False   16.0
# SURFNEBUL.BASSE     187     False   16.0
# SURFCAPE.MOD.XFU    188     False   16.0
# CLPMOCON.MOD.XFU    189     False   16.0
# CLSVENT.ZONAL       190     False   16.0
# CLSVENT.MERIDIEN    191     False   16.0
# CLSTEMPERATURE      192     False   16.0
# CLSHUMI.RELATIVE    193     False   16.0
# CLSHUMI.SPECIFIQ    194     False   16.0
# CLSMINI.H.TEMPER    195     False   16.0
# CLSMAXI.H.TEMPER    196     False   16.0
# CLPMHAUT.MOD.XFU    197     False   16.0
# CLSU.RAF.MOD.XFU    198     False   16.0
# CLSV.RAF.MOD.XFU    199     False   16.0
# SURFTENS.DMOG.ZO    200     False   16.0
# SURFTENS.DMOG.ME    201     False   16.0
# SURFTENS.TURB.ZO    202     False   16.0
# SURFTENS.TURB.ME    203     False   16.0
# SURFCFU.Q.TURBUL    204     False   16.0
# SURFCFU.CT.TURBU    205     False   16.0
# SURFPREC.EAU.CON    206     False   16.0
# SURFFL.COND.L.CO    207     False   16.0
# SURFPREC.NEI.CON    208     False   16.0
# SURFFL.COND.N.CO    209     False   16.0
# SURFPREC.EAU.GEC    210     False   16.0
# SURFFL.COND.L.GE    211     False   16.0
# SURFPREC.NEI.GEC    212     False   16.0
# SURFFL.COND.N.GE    213     False   16.0
# SOMMFLU.RAY.SOLA    214     False   16.0
# SURFFLU.RAY.SOLA    215     False   16.0
# SOMMFLU.RAY.THER    216     False   16.0
# SURFFLU.RAY.THER    217     False   16.0
# SURFFLU.LAT.MEVA    218     False   16.0
# SURFFLU.LAT.MSUB    219     False   16.0
# SURFFLU.MEVAP.EA    220     False   16.0
# SURFFLU.MSUBL.NE    221     False   16.0
# SURFFLU.CHA.SENS    222     False   16.0
# SURFRAYT DIR SUR    227     False   16.0
# TOPRAYT DIR SOM     228     False   16.0
# SURFDIR NORM IRR    229     False   16.0
# SURFRAYT SOLA DE    230     False   16.0
# SURFRAYT THER DE    231     False   16.0
# SURFPRESSION        372     True    18.0
# SPECSURFGEOPOTEN    373     True    nan
#
# ########## 3D #########
#
# Base-name          Full-name example  spectral  nbits levels
# -------------------------------------------------------------
# SNOW                S001SNOW           False     16.0  1 - 46
# RAIN                S001RAIN           False     16.0  1 - 46
# RK_QCTEND           S001RK_QCTEND      False     16.0  1 - 46
# RAYT SOL CL         S001RAYT SOL CL    False     16.0  [1, 46]
# RAYT THER CL        S001RAYT THER CL   False     16.0  [1, 46]
# HUMI.SPECIFI        S001HUMI.SPECIFI   True      18.0  1 - 46
# TEMPERATURE         S001TEMPERATURE    True      18.0  1 - 46
# WIND.U.PHYS         S001WIND.U.PHYS    True      18.0  1 - 46
# WIND.V.PHYS         S001WIND.V.PHYS    True      18.0  1 - 46

# %% [markdown]
# ## FaDataset Class
#
# The FaFile class was just for printing out and inspecting the metadata of a FA file. If we want to use the data itself, we need the FaDataset class.
#
# The FaDataset class is designed to convert a Fa file to an xarray.Dataset object, which will be stored as the `ds` attribute. You can directly use and manipulate this attribute if you like.
#
# There are three methods to import a FA file (*importing means to convert an FA file to an xarray.Dataset*):
# * using `import_2d_field()`: This method is designed to only import a single two-dimensional field.
# * using `import_3d_field()`: This methods is designed to import all 2d fields to construct a 3d field. This is done by specifying a `basename` which is the equivalent of the fieldname but without the level specifier. i.g. *TEMPERATURE* is the `basename` for all 2d fields like *S001TEMPERATURE*, *S002TEMPERATURE*, ...
# *  using `import_fa()`: This is a general method where you have control over all the fields (2d and 3d) that will be imported.

# %% [markdown]
# ### Import a 2D and 3D field
# We saw in the .describe of the fafile that `CLSVENT.ZONAL` (2d) and `WIND.V.PHYS` (3d) are available. As an example we will read these fields separately:

# %%
# Import the CLS zonal 2D field as a dataset
cls_wind_data = pyfa.FaDataset(fafile=pyfa.demo_fa)
cls_wind_data.import_2d_field(fieldname='CLSVENT.ZONAL')
print(cls_wind_data)
# Out:
# [1] "PROFTEMPERATURE  not in whitelist"
# [1] "PROFRESERV.EAU   not in whitelist"
# [1] "PROFRESERV.GLACE not in whitelist"
# [1] "SURFRESERV.NEIGE not in whitelist"
# [1] "SURFALBEDO NEIGE not in whitelist"
# [1] "SURFDENSIT.NEIGE not in whitelist"
# [1] "SURFALBEDO HISTO not in whitelist"
# [1] "SURFTEMPERATURE  not in whitelist"
# [1] "SURFRESERV.EAU   not in whitelist"
# [1] "SURFRESERV.INTER not in whitelist"
# [1] "SURFRESERV.GLACE not in whitelist"
# [1] "SURFZ0.FOIS.G    not in whitelist"
# [1] "SURFALBEDO       not in whitelist"
# [1] "SURFEMISSIVITE   not in whitelist"
# [1] "SURFET.GEOPOTENT not in whitelist"
# [1] "SURFIND.TERREMER not in whitelist"
# [1] "SURFPROP.VEGETAT not in whitelist"
# [1] "SURFVAR.GEOP.ANI not in whitelist"
# [1] "SURFVAR.GEOP.DIR not in whitelist"
# [1] "SURFPROP.ARGILE  not in whitelist"
# [1] "SURFPROP.SABLE   not in whitelist"
# [1] "SURFEPAIS.SOL    not in whitelist"
# [1] "SURFIND.VEG.DOMI not in whitelist"
# [1] "SURFRESI.STO.MIN not in whitelist"
# [1] "SURFIND.FOLIAIRE not in whitelist"
# [1] "SURFRES.EVAPOTRA not in whitelist"
# [1] "SURFGZ0.THERM    not in whitelist"
# [1] "SURFALBEDO.SOLNU not in whitelist"
# [1] "SURFALBEDO.VEG   not in whitelist"
# [1] "SURFAEROS.SEA    not in whitelist"
# [1] "SURFAEROS.LAND   not in whitelist"
# [1] "SURFAEROS.SOOT   not in whitelist"
# [1] "SURFAEROS.DESERT not in whitelist"
# [1] "SURFA.OF.OZONE   not in whitelist"
# [1] "SURFB.OF.OZONE   not in whitelist"
# [1] "SURFC.OF.OZONE   not in whitelist"
# [1] "SUNSHI. DURATION not in whitelist"
# [1] "SURFNEBUL.TOTALE not in whitelist"
# [1] "SURFNEBUL.CONVEC not in whitelist"
# [1] "SURFNEBUL.HAUTE  not in whitelist"
# [1] "SURFNEBUL.MOYENN not in whitelist"
# [1] "SURFNEBUL.BASSE  not in whitelist"
# [1] "SURFCAPE.MOD.XFU not in whitelist"
# [1] "CLPMOCON.MOD.XFU not in whitelist"
# [1] "CLSVENT.ZONAL    reading ..."
# [1] "CLSVENT.MERIDIEN not in whitelist"
# [1] "CLSTEMPERATURE   not in whitelist"
# [1] "CLSHUMI.RELATIVE not in whitelist"
# [1] "CLSHUMI.SPECIFIQ not in whitelist"
# [1] "CLSMINI.H.TEMPER not in whitelist"
# [1] "CLSMAXI.H.TEMPER not in whitelist"
# [1] "CLPMHAUT.MOD.XFU not in whitelist"
# [1] "CLSU.RAF.MOD.XFU not in whitelist"
# [1] "CLSV.RAF.MOD.XFU not in whitelist"
# [1] "SURFTENS.DMOG.ZO not in whitelist"
# [1] "SURFTENS.DMOG.ME not in whitelist"
# [1] "SURFTENS.TURB.ZO not in whitelist"
# [1] "SURFTENS.TURB.ME not in whitelist"
# [1] "SURFCFU.Q.TURBUL not in whitelist"
# [1] "SURFCFU.CT.TURBU not in whitelist"
# [1] "SURFPREC.EAU.CON not in whitelist"
# [1] "SURFFL.COND.L.CO not in whitelist"
# [1] "SURFPREC.NEI.CON not in whitelist"
# [1] "SURFFL.COND.N.CO not in whitelist"
# [1] "SURFPREC.EAU.GEC not in whitelist"
# [1] "SURFFL.COND.L.GE not in whitelist"
# [1] "SURFPREC.NEI.GEC not in whitelist"
# [1] "SURFFL.COND.N.GE not in whitelist"
# [1] "SOMMFLU.RAY.SOLA not in whitelist"
# [1] "SURFFLU.RAY.SOLA not in whitelist"
# [1] "SOMMFLU.RAY.THER not in whitelist"
# [1] "SURFFLU.RAY.THER not in whitelist"
# [1] "SURFFLU.LAT.MEVA not in whitelist"
# [1] "SURFFLU.LAT.MSUB not in whitelist"
# [1] "SURFFLU.MEVAP.EA not in whitelist"
# [1] "SURFFLU.MSUBL.NE not in whitelist"
# [1] "SURFFLU.CHA.SENS not in whitelist"
# [1] "SURFRAYT DIR SUR not in whitelist"
# [1] "TOPRAYT DIR SOM  not in whitelist"
# [1] "SURFDIR NORM IRR not in whitelist"
# [1] "SURFRAYT SOLA DE not in whitelist"
# [1] "SURFRAYT THER DE not in whitelist"
# [1] "SURFPRESSION     not in whitelist"
# [1] "SPECSURFGEOPOTEN not in whitelist"
# [1] "SNOW         not in whitelist"
# [1] "RAIN         not in whitelist"
# [1] "RK_QCTEND    not in whitelist"
# [1] "RAYT SOL CL  not in whitelist"
# [1] "RAYT THER CL not in whitelist"
# [1] "HUMI.SPECIFI not in whitelist"
# [1] "TEMPERATURE  not in whitelist"
# [1] "WIND.U.PHYS  not in whitelist"
# [1] "WIND.V.PHYS  not in whitelist"
# Reading json data
# <xarray.Dataset>
# Dimensions:        (y: 251, x: 251, level: 46, validate: 1, basedate: 1)
# Coordinates:
#   * x              (x) int64 -3125000 -3100000 -3075000 ... 3100000 3125000
#   * y              (y) float64 2.974e+06 2.999e+06 ... 9.199e+06 9.224e+06
#   * level          (level) int64 0 1 2 3 4 5 6 7 8 ... 38 39 40 41 42 43 44 45
#     spatial_ref    int64 0
#   * validate       (validate) datetime64[ns] 2022-12-31T12:00:00
#   * basedate       (basedate) datetime64[ns] 2022-12-01
# Data variables:
#     CLSVENT.ZONAL  (y, x) float64 -6.452 -6.492 -6.652 ... -1.988 -2.006 -1.84
# Attributes: (12/20)
#     timestep:     450
#     origin:       /home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHA...
#     projection:   +proj=lcc +lat_1=49 +lat_2=49 +lon_0=9.9 +R=6371229
#     nx:           251
#     ny:           251
#     dx:           25000
#     ...           ...
#     ndgux:        251
#     nsmax:        134
#     nlev:         46
#     refpressure:  101325.0
#     A_list:       [0.     0.0001 0.0003 0.0007 0.0013 0.0023 0.0045 0.0051 0....
#     B_list:       [0.     0.0001 0.0003 0.0007 0.0013 0.0023 0.0045 0.0051 0....

# %% [markdown]
# *Note: You can see that the dimensions of the xarray.dataset include the levels even for a 2D field. This is done so all methods are applicable on all types of dataset 2d, 3d or a combination of both. If you look carefully you can see that the variable `CLSVENT.ZONAL` has only the `(y, x)` dimensions, so it is a 2d field.*

# %%
#if you want to work directly with the xarray dataset you can do this by working with the .ds attribute:
cls_wind_data.ds['CLSVENT.ZONAL'].data.max()
# Out:
# 21.2439

# %%
# Import the WIND.V.PHYS 3D field as a dataset
d3wind_data = pyfa.FaDataset(fafile=pyfa.demo_fa)
d3wind_data.import_3d_field(fieldname='WIND.V.PHYS')
print(d3wind_data)
# Out:
# [1] "PROFTEMPERATURE  not in whitelist"
# [1] "PROFRESERV.EAU   not in whitelist"
# [1] "PROFRESERV.GLACE not in whitelist"
# [1] "SURFRESERV.NEIGE not in whitelist"
# [1] "SURFALBEDO NEIGE not in whitelist"
# [1] "SURFDENSIT.NEIGE not in whitelist"
# [1] "SURFALBEDO HISTO not in whitelist"
# [1] "SURFTEMPERATURE  not in whitelist"
# [1] "SURFRESERV.EAU   not in whitelist"
# [1] "SURFRESERV.INTER not in whitelist"
# [1] "SURFRESERV.GLACE not in whitelist"
# [1] "SURFZ0.FOIS.G    not in whitelist"
# [1] "SURFALBEDO       not in whitelist"
# [1] "SURFEMISSIVITE   not in whitelist"
# [1] "SURFET.GEOPOTENT not in whitelist"
# [1] "SURFIND.TERREMER not in whitelist"
# [1] "SURFPROP.VEGETAT not in whitelist"
# [1] "SURFVAR.GEOP.ANI not in whitelist"
# [1] "SURFVAR.GEOP.DIR not in whitelist"
# [1] "SURFPROP.ARGILE  not in whitelist"
# [1] "SURFPROP.SABLE   not in whitelist"
# [1] "SURFEPAIS.SOL    not in whitelist"
# [1] "SURFIND.VEG.DOMI not in whitelist"
# [1] "SURFRESI.STO.MIN not in whitelist"
# [1] "SURFIND.FOLIAIRE not in whitelist"
# [1] "SURFRES.EVAPOTRA not in whitelist"
# [1] "SURFGZ0.THERM    not in whitelist"
# [1] "SURFALBEDO.SOLNU not in whitelist"
# [1] "SURFALBEDO.VEG   not in whitelist"
# [1] "SURFAEROS.SEA    not in whitelist"
# [1] "SURFAEROS.LAND   not in whitelist"
# [1] "SURFAEROS.SOOT   not in whitelist"
# [1] "SURFAEROS.DESERT not in whitelist"
# [1] "SURFA.OF.OZONE   not in whitelist"
# [1] "SURFB.OF.OZONE   not in whitelist"
# [1] "SURFC.OF.OZONE   not in whitelist"
# [1] "SUNSHI. DURATION not in whitelist"
# [1] "SURFNEBUL.TOTALE not in whitelist"
# [1] "SURFNEBUL.CONVEC not in whitelist"
# [1] "SURFNEBUL.HAUTE  not in whitelist"
# [1] "SURFNEBUL.MOYENN not in whitelist"
# [1] "SURFNEBUL.BASSE  not in whitelist"
# [1] "SURFCAPE.MOD.XFU not in whitelist"
# [1] "CLPMOCON.MOD.XFU not in whitelist"
# [1] "CLSVENT.ZONAL    not in whitelist"
# [1] "CLSVENT.MERIDIEN not in whitelist"
# [1] "CLSTEMPERATURE   not in whitelist"
# [1] "CLSHUMI.RELATIVE not in whitelist"
# [1] "CLSHUMI.SPECIFIQ not in whitelist"
# [1] "CLSMINI.H.TEMPER not in whitelist"
# [1] "CLSMAXI.H.TEMPER not in whitelist"
# [1] "CLPMHAUT.MOD.XFU not in whitelist"
# [1] "CLSU.RAF.MOD.XFU not in whitelist"
# [1] "CLSV.RAF.MOD.XFU not in whitelist"
# [1] "SURFTENS.DMOG.ZO not in whitelist"
# [1] "SURFTENS.DMOG.ME not in whitelist"
# [1] "SURFTENS.TURB.ZO not in whitelist"
# [1] "SURFTENS.TURB.ME not in whitelist"
# [1] "SURFCFU.Q.TURBUL not in whitelist"
# [1] "SURFCFU.CT.TURBU not in whitelist"
# [1] "SURFPREC.EAU.CON not in whitelist"
# [1] "SURFFL.COND.L.CO not in whitelist"
# [1] "SURFPREC.NEI.CON not in whitelist"
# [1] "SURFFL.COND.N.CO not in whitelist"
# [1] "SURFPREC.EAU.GEC not in whitelist"
# [1] "SURFFL.COND.L.GE not in whitelist"
# [1] "SURFPREC.NEI.GEC not in whitelist"
# [1] "SURFFL.COND.N.GE not in whitelist"
# [1] "SOMMFLU.RAY.SOLA not in whitelist"
# [1] "SURFFLU.RAY.SOLA not in whitelist"
# [1] "SOMMFLU.RAY.THER not in whitelist"
# [1] "SURFFLU.RAY.THER not in whitelist"
# [1] "SURFFLU.LAT.MEVA not in whitelist"
# [1] "SURFFLU.LAT.MSUB not in whitelist"
# [1] "SURFFLU.MEVAP.EA not in whitelist"
# [1] "SURFFLU.MSUBL.NE not in whitelist"
# [1] "SURFFLU.CHA.SENS not in whitelist"
# [1] "SURFRAYT DIR SUR not in whitelist"
# [1] "TOPRAYT DIR SOM  not in whitelist"
# [1] "SURFDIR NORM IRR not in whitelist"
# [1] "SURFRAYT SOLA DE not in whitelist"
# [1] "SURFRAYT THER DE not in whitelist"
# [1] "SURFPRESSION     not in whitelist"
# [1] "SPECSURFGEOPOTEN not in whitelist"
# [1] "SNOW         not in whitelist"
# [1] "RAIN         not in whitelist"
# [1] "RK_QCTEND    not in whitelist"
# [1] "RAYT SOL CL  not in whitelist"
# [1] "RAYT THER CL not in whitelist"
# [1] "HUMI.SPECIFI not in whitelist"
# [1] "TEMPERATURE  not in whitelist"
# [1] "WIND.U.PHYS  not in whitelist"
# [1] "WIND.V.PHYS  reading ..."
# Reading json data
# <xarray.Dataset>
# Dimensions:      (level: 46, y: 251, x: 251, validate: 1, basedate: 1)
# Coordinates:
#   * x            (x) int64 -3125000 -3100000 -3075000 ... 3100000 3125000
#   * y            (y) float64 2.974e+06 2.999e+06 ... 9.199e+06 9.224e+06
#   * level        (level) int64 0 1 2 3 4 5 6 7 8 ... 37 38 39 40 41 42 43 44 45
#     spatial_ref  int64 0
#   * validate     (validate) datetime64[ns] 2022-12-31T12:00:00
#   * basedate     (basedate) datetime64[ns] 2022-12-01
# Data variables:
#     WIND.V.PHYS  (y, x, level) float64 -16.51 -5.158 -3.026 ... -4.913 -3.546
# Attributes: (12/20)
#     timestep:     450
#     origin:       /home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHA...
#     projection:   +proj=lcc +lat_1=49 +lat_2=49 +lon_0=9.9 +R=6371229
#     nx:           251
#     ny:           251
#     dx:           25000
#     ...           ...
#     ndgux:        251
#     nsmax:        134
#     nlev:         46
#     refpressure:  101325.0
#     A_list:       [0.     0.0001 0.0003 0.0007 0.0013 0.0023 0.0045 0.0051 0....
#     B_list:       [0.     0.0001 0.0003 0.0007 0.0013 0.0023 0.0045 0.0051 0....

# %%
#basic windprofile at a random location
d3wind_data.ds['WIND.V.PHYS'].sel(x=-150000, y=7923687.901).plot()

# %%
# Import multiple fields

full_data = pyfa.FaDataset(fafile=pyfa.demo_fa)

# To import all fields: 
#(Whitelist specifies all the fields (2d and 3d) to read, blacklist are all the fields to skip)

#This can take a couple of seconds.
full_data.import_fa(whitelist=None, #If none, all fields are interpreted as white 
                    blacklist=None, #If none, blacklist is empty
                   )
print(full_data.get_fieldnames())
# Out:
# [1] "PROFTEMPERATURE  reading ..."
# [1] "PROFRESERV.EAU   reading ..."
# [1] "PROFRESERV.GLACE reading ..."
# [1] "SURFRESERV.NEIGE reading ..."
# [1] "SURFALBEDO NEIGE reading ..."
# [1] "SURFDENSIT.NEIGE reading ..."
# [1] "SURFALBEDO HISTO reading ..."
# [1] "SURFTEMPERATURE  reading ..."
# [1] "SURFRESERV.EAU   reading ..."
# [1] "SURFRESERV.INTER reading ..."
# [1] "SURFRESERV.GLACE reading ..."
# [1] "SURFZ0.FOIS.G    reading ..."
# [1] "SURFALBEDO       reading ..."
# [1] "SURFEMISSIVITE   reading ..."
# [1] "SURFET.GEOPOTENT reading ..."
# [1] "SURFIND.TERREMER reading ..."
# [1] "SURFPROP.VEGETAT reading ..."
# [1] "SURFVAR.GEOP.ANI reading ..."
# [1] "SURFVAR.GEOP.DIR reading ..."
# [1] "SURFPROP.ARGILE  reading ..."
# [1] "SURFPROP.SABLE   reading ..."
# [1] "SURFEPAIS.SOL    reading ..."
# [1] "SURFIND.VEG.DOMI reading ..."
# [1] "SURFRESI.STO.MIN reading ..."
# [1] "SURFIND.FOLIAIRE reading ..."
# [1] "SURFRES.EVAPOTRA reading ..."
# [1] "SURFGZ0.THERM    reading ..."
# [1] "SURFALBEDO.SOLNU reading ..."
# [1] "SURFALBEDO.VEG   reading ..."
# [1] "SURFAEROS.SEA    reading ..."
# [1] "SURFAEROS.LAND   reading ..."
# [1] "SURFAEROS.SOOT   reading ..."
# [1] "SURFAEROS.DESERT reading ..."
# [1] "SURFA.OF.OZONE   reading ..."
# [1] "SURFB.OF.OZONE   reading ..."
# [1] "SURFC.OF.OZONE   reading ..."
# [1] "SUNSHI. DURATION reading ..."
# [1] "SURFNEBUL.TOTALE reading ..."
# [1] "SURFNEBUL.CONVEC reading ..."
# [1] "SURFNEBUL.HAUTE  reading ..."
# [1] "SURFNEBUL.MOYENN reading ..."
# [1] "SURFNEBUL.BASSE  reading ..."
# [1] "SURFCAPE.MOD.XFU reading ..."
# [1] "CLPMOCON.MOD.XFU reading ..."
# [1] "CLSVENT.ZONAL    reading ..."
# [1] "CLSVENT.MERIDIEN reading ..."
# [1] "CLSTEMPERATURE   reading ..."
# [1] "CLSHUMI.RELATIVE reading ..."
# [1] "CLSHUMI.SPECIFIQ reading ..."
# [1] "CLSMINI.H.TEMPER reading ..."
# [1] "CLSMAXI.H.TEMPER reading ..."
# [1] "CLPMHAUT.MOD.XFU reading ..."
# [1] "CLSU.RAF.MOD.XFU reading ..."
# [1] "CLSV.RAF.MOD.XFU reading ..."
# [1] "SURFTENS.DMOG.ZO reading ..."
# [1] "SURFTENS.DMOG.ME reading ..."
# [1] "SURFTENS.TURB.ZO reading ..."
# [1] "SURFTENS.TURB.ME reading ..."
# [1] "SURFCFU.Q.TURBUL reading ..."
# [1] "SURFCFU.CT.TURBU reading ..."
# [1] "SURFPREC.EAU.CON reading ..."
# [1] "SURFFL.COND.L.CO reading ..."
# [1] "SURFPREC.NEI.CON reading ..."
# [1] "SURFFL.COND.N.CO reading ..."
# [1] "SURFPREC.EAU.GEC reading ..."
# [1] "SURFFL.COND.L.GE reading ..."
# [1] "SURFPREC.NEI.GEC reading ..."
# [1] "SURFFL.COND.N.GE reading ..."
# [1] "SOMMFLU.RAY.SOLA reading ..."
# [1] "SURFFLU.RAY.SOLA reading ..."
# [1] "SOMMFLU.RAY.THER reading ..."
# [1] "SURFFLU.RAY.THER reading ..."
# [1] "SURFFLU.LAT.MEVA reading ..."
# [1] "SURFFLU.LAT.MSUB reading ..."
# [1] "SURFFLU.MEVAP.EA reading ..."
# [1] "SURFFLU.MSUBL.NE reading ..."
# [1] "SURFFLU.CHA.SENS reading ..."
# [1] "SURFRAYT DIR SUR reading ..."
# [1] "TOPRAYT DIR SOM  reading ..."
# [1] "SURFDIR NORM IRR reading ..."
# [1] "SURFRAYT SOLA DE reading ..."
# [1] "SURFRAYT THER DE reading ..."
# [1] "SURFPRESSION     reading ..."
# [1] "SPECSURFGEOPOTEN reading ..."
# [1] "SNOW         reading ..."
# [1] "RAIN         reading ..."
# [1] "RK_QCTEND    reading ..."
# [1] "RAYT SOL CL  reading ..."
# <simpleError in dimnames(result) <- list(x = NULL, y = NULL, hybrid = minlev:maxlev): length of 'dimnames' [3] not equal to array extent>
# [1] "RAYT THER CL reading ..."
# <simpleError in dimnames(result) <- list(x = NULL, y = NULL, hybrid = minlev:maxlev): length of 'dimnames' [3] not equal to array extent>
# [1] "HUMI.SPECIFI reading ..."
# An Error Occurred for this 3d field
# An Error Occurred for this 3d field
# [1] "TEMPERATURE  reading ..."
# [1] "WIND.U.PHYS  reading ..."
# [1] "WIND.V.PHYS  reading ..."
# Warning messages:
# 1: In FAdec.FAfile(fa, fields) :
#   Fields S002RAYT SOL CL , S003RAYT SOL CL , S004RAYT SOL CL , S005RAYT SOL CL , S006RAYT SOL CL , S007RAYT SOL CL , S008RAYT SOL CL , S009RAYT SOL CL , S010RAYT SOL CL , S011RAYT SOL CL , S012RAYT SOL CL , S013RAYT SOL CL , S014RAYT SOL CL , S015RAYT SOL CL , S016RAYT SOL CL , S017RAYT SOL CL , S018RAYT SOL CL , S019RAYT SOL CL , S020RAYT SOL CL , S021RAYT SOL CL , S022RAYT SOL CL , S023RAYT SOL CL , S024RAYT SOL CL , S025RAYT SOL CL , S026RAYT SOL CL , S027RAYT SOL CL , S028RAYT SOL CL , S029RAYT SOL CL , S030RAYT SOL CL , S031RAYT SOL CL , S032RAYT SOL CL , S033RAYT SOL CL , S034RAYT SOL CL , S035RAYT SOL CL , S036RAYT SOL CL , S037RAYT SOL CL , S038RAYT SOL CL , S039RAYT SOL CL , S040RAYT SOL CL , S041RAYT SOL CL , S042RAYT SOL CL , S043RAYT SOL CL , S044RAYT SOL CL , S045RAYT SOL CL  not found.
# 2: In FAdec.FAfile(fa, fields) :
#   Fields S002RAYT THER CL, S003RAYT THER CL, S004RAYT THER CL, S005RAYT THER CL, S006RAYT THER CL, S007RAYT THER CL, S008RAYT THER CL, S009RAYT THER CL, S010RAYT THER CL, S011RAYT THER CL, S012RAYT THER CL, S013RAYT THER CL, S014RAYT THER CL, S015RAYT THER CL, S016RAYT THER CL, S017RAYT THER CL, S018RAYT THER CL, S019RAYT THER CL, S020RAYT THER CL, S021RAYT THER CL, S022RAYT THER CL, S023RAYT THER CL, S024RAYT THER CL, S025RAYT THER CL, S026RAYT THER CL, S027RAYT THER CL, S028RAYT THER CL, S029RAYT THER CL, S030RAYT THER CL, S031RAYT THER CL, S032RAYT THER CL, S033RAYT THER CL, S034RAYT THER CL, S035RAYT THER CL, S036RAYT THER CL, S037RAYT THER CL, S038RAYT THER CL, S039RAYT THER CL, S040RAYT THER CL, S041RAYT THER CL, S042RAYT THER CL, S043RAYT THER CL, S044RAYT THER CL, S045RAYT THER CL not found.
# Reading json data
# ['PROFTEMPERATURE', 'PROFRESERV.EAU', 'PROFRESERV.GLACE', 'SURFRESERV.NEIGE', 'SURFALBEDO NEIGE', 'SURFDENSIT.NEIGE', 'SURFALBEDO HISTO', 'SURFTEMPERATURE', 'SURFRESERV.EAU', 'SURFRESERV.INTER', 'SURFRESERV.GLACE', 'SURFZ0.FOIS.G', 'SURFALBEDO', 'SURFEMISSIVITE', 'SURFET.GEOPOTENT', 'SURFIND.TERREMER', 'SURFPROP.VEGETAT', 'SURFVAR.GEOP.ANI', 'SURFVAR.GEOP.DIR', 'SURFPROP.ARGILE', 'SURFPROP.SABLE', 'SURFEPAIS.SOL', 'SURFIND.VEG.DOMI', 'SURFRESI.STO.MIN', 'SURFIND.FOLIAIRE', 'SURFRES.EVAPOTRA', 'SURFGZ0.THERM', 'SURFALBEDO.SOLNU', 'SURFALBEDO.VEG', 'SURFAEROS.SEA', 'SURFAEROS.LAND', 'SURFAEROS.SOOT', 'SURFAEROS.DESERT', 'SURFA.OF.OZONE', 'SURFB.OF.OZONE', 'SURFC.OF.OZONE', 'SUNSHI. DURATION', 'SURFNEBUL.TOTALE', 'SURFNEBUL.CONVEC', 'SURFNEBUL.HAUTE', 'SURFNEBUL.MOYENN', 'SURFNEBUL.BASSE', 'SURFCAPE.MOD.XFU', 'CLPMOCON.MOD.XFU', 'CLSVENT.ZONAL', 'CLSVENT.MERIDIEN', 'CLSTEMPERATURE', 'CLSHUMI.RELATIVE', 'CLSHUMI.SPECIFIQ', 'CLSMINI.H.TEMPER', 'CLSMAXI.H.TEMPER', 'CLPMHAUT.MOD.XFU', 'CLSU.RAF.MOD.XFU', 'CLSV.RAF.MOD.XFU', 'SURFTENS.DMOG.ZO', 'SURFTENS.DMOG.ME', 'SURFTENS.TURB.ZO', 'SURFTENS.TURB.ME', 'SURFCFU.Q.TURBUL', 'SURFCFU.CT.TURBU', 'SURFPREC.EAU.CON', 'SURFFL.COND.L.CO', 'SURFPREC.NEI.CON', 'SURFFL.COND.N.CO', 'SURFPREC.EAU.GEC', 'SURFFL.COND.L.GE', 'SURFPREC.NEI.GEC', 'SURFFL.COND.N.GE', 'SOMMFLU.RAY.SOLA', 'SURFFLU.RAY.SOLA', 'SOMMFLU.RAY.THER', 'SURFFLU.RAY.THER', 'SURFFLU.LAT.MEVA', 'SURFFLU.LAT.MSUB', 'SURFFLU.MEVAP.EA', 'SURFFLU.MSUBL.NE', 'SURFFLU.CHA.SENS', 'SURFRAYT DIR SUR', 'TOPRAYT DIR SOM', 'SURFDIR NORM IRR', 'SURFRAYT SOLA DE', 'SURFRAYT THER DE', 'SURFPRESSION', 'SPECSURFGEOPOTEN', 'SNOW', 'RAIN', 'RK_QCTEND', 'HUMI.SPECIFI', 'TEMPERATURE', 'WIND.U.PHYS', 'WIND.V.PHYS']

# %%
# If you are only interested in a certain set of field, you can set the white and blacklist accordingly:
full_data.import_fa(whitelist=["PROFTEMPERATURE", "SURFALBEDO.VEG", "TEMPERATURE"], 
                    blacklist=None, #If none, blacklist is empty
                   )

print(full_data)
# Out:
# [1] "PROFTEMPERATURE  reading ..."
# [1] "PROFRESERV.EAU   not in whitelist"
# [1] "PROFRESERV.GLACE not in whitelist"
# [1] "SURFRESERV.NEIGE not in whitelist"
# [1] "SURFALBEDO NEIGE not in whitelist"
# [1] "SURFDENSIT.NEIGE not in whitelist"
# [1] "SURFALBEDO HISTO not in whitelist"
# [1] "SURFTEMPERATURE  not in whitelist"
# [1] "SURFRESERV.EAU   not in whitelist"
# [1] "SURFRESERV.INTER not in whitelist"
# [1] "SURFRESERV.GLACE not in whitelist"
# [1] "SURFZ0.FOIS.G    not in whitelist"
# [1] "SURFALBEDO       not in whitelist"
# [1] "SURFEMISSIVITE   not in whitelist"
# [1] "SURFET.GEOPOTENT not in whitelist"
# [1] "SURFIND.TERREMER not in whitelist"
# [1] "SURFPROP.VEGETAT not in whitelist"
# [1] "SURFVAR.GEOP.ANI not in whitelist"
# [1] "SURFVAR.GEOP.DIR not in whitelist"
# [1] "SURFPROP.ARGILE  not in whitelist"
# [1] "SURFPROP.SABLE   not in whitelist"
# [1] "SURFEPAIS.SOL    not in whitelist"
# [1] "SURFIND.VEG.DOMI not in whitelist"
# [1] "SURFRESI.STO.MIN not in whitelist"
# [1] "SURFIND.FOLIAIRE not in whitelist"
# [1] "SURFRES.EVAPOTRA not in whitelist"
# [1] "SURFGZ0.THERM    not in whitelist"
# [1] "SURFALBEDO.SOLNU not in whitelist"
# [1] "SURFALBEDO.VEG   reading ..."
# [1] "SURFAEROS.SEA    not in whitelist"
# [1] "SURFAEROS.LAND   not in whitelist"
# [1] "SURFAEROS.SOOT   not in whitelist"
# [1] "SURFAEROS.DESERT not in whitelist"
# [1] "SURFA.OF.OZONE   not in whitelist"
# [1] "SURFB.OF.OZONE   not in whitelist"
# [1] "SURFC.OF.OZONE   not in whitelist"
# [1] "SUNSHI. DURATION not in whitelist"
# [1] "SURFNEBUL.TOTALE not in whitelist"
# [1] "SURFNEBUL.CONVEC not in whitelist"
# [1] "SURFNEBUL.HAUTE  not in whitelist"
# [1] "SURFNEBUL.MOYENN not in whitelist"
# [1] "SURFNEBUL.BASSE  not in whitelist"
# [1] "SURFCAPE.MOD.XFU not in whitelist"
# [1] "CLPMOCON.MOD.XFU not in whitelist"
# [1] "CLSVENT.ZONAL    not in whitelist"
# [1] "CLSVENT.MERIDIEN not in whitelist"
# [1] "CLSTEMPERATURE   not in whitelist"
# [1] "CLSHUMI.RELATIVE not in whitelist"
# [1] "CLSHUMI.SPECIFIQ not in whitelist"
# [1] "CLSMINI.H.TEMPER not in whitelist"
# [1] "CLSMAXI.H.TEMPER not in whitelist"
# [1] "CLPMHAUT.MOD.XFU not in whitelist"
# [1] "CLSU.RAF.MOD.XFU not in whitelist"
# [1] "CLSV.RAF.MOD.XFU not in whitelist"
# [1] "SURFTENS.DMOG.ZO not in whitelist"
# [1] "SURFTENS.DMOG.ME not in whitelist"
# [1] "SURFTENS.TURB.ZO not in whitelist"
# [1] "SURFTENS.TURB.ME not in whitelist"
# [1] "SURFCFU.Q.TURBUL not in whitelist"
# [1] "SURFCFU.CT.TURBU not in whitelist"
# [1] "SURFPREC.EAU.CON not in whitelist"
# [1] "SURFFL.COND.L.CO not in whitelist"
# [1] "SURFPREC.NEI.CON not in whitelist"
# [1] "SURFFL.COND.N.CO not in whitelist"
# [1] "SURFPREC.EAU.GEC not in whitelist"
# [1] "SURFFL.COND.L.GE not in whitelist"
# [1] "SURFPREC.NEI.GEC not in whitelist"
# [1] "SURFFL.COND.N.GE not in whitelist"
# [1] "SOMMFLU.RAY.SOLA not in whitelist"
# [1] "SURFFLU.RAY.SOLA not in whitelist"
# [1] "SOMMFLU.RAY.THER not in whitelist"
# [1] "SURFFLU.RAY.THER not in whitelist"
# [1] "SURFFLU.LAT.MEVA not in whitelist"
# [1] "SURFFLU.LAT.MSUB not in whitelist"
# [1] "SURFFLU.MEVAP.EA not in whitelist"
# [1] "SURFFLU.MSUBL.NE not in whitelist"
# [1] "SURFFLU.CHA.SENS not in whitelist"
# [1] "SURFRAYT DIR SUR not in whitelist"
# [1] "TOPRAYT DIR SOM  not in whitelist"
# [1] "SURFDIR NORM IRR not in whitelist"
# [1] "SURFRAYT SOLA DE not in whitelist"
# [1] "SURFRAYT THER DE not in whitelist"
# [1] "SURFPRESSION     not in whitelist"
# [1] "SPECSURFGEOPOTEN not in whitelist"
# [1] "SNOW         not in whitelist"
# [1] "RAIN         not in whitelist"
# [1] "RK_QCTEND    not in whitelist"
# [1] "RAYT SOL CL  not in whitelist"
# [1] "RAYT THER CL not in whitelist"
# [1] "HUMI.SPECIFI not in whitelist"
# [1] "TEMPERATURE  reading ..."
# [1] "WIND.U.PHYS  not in whitelist"
# [1] "WIND.V.PHYS  not in whitelist"
# Reading json data
# <xarray.Dataset>
# Dimensions:          (y: 251, x: 251, level: 46, validate: 1, basedate: 1)
# Coordinates:
#   * x                (x) int64 -3125000 -3100000 -3075000 ... 3100000 3125000
#   * y                (y) float64 2.974e+06 2.999e+06 ... 9.199e+06 9.224e+06
#   * level            (level) int64 0 1 2 3 4 5 6 7 8 ... 38 39 40 41 42 43 44 45
#     spatial_ref      int64 0
#   * validate         (validate) datetime64[ns] 2022-12-31T12:00:00
#   * basedate         (basedate) datetime64[ns] 2022-12-01
# Data variables:
#     PROFTEMPERATURE  (y, x) float64 295.7 294.6 297.6 ... 257.9 258.4 259.2
#     SURFALBEDO.VEG   (y, x) float64 0.05 0.05 0.25 0.25 ... 0.1272 0.1367 0.1373
#     TEMPERATURE      (y, x, level) float64 212.9 232.2 245.4 ... 246.5 245.8
# Attributes: (12/20)
#     timestep:     450
#     origin:       /home/thoverga/Documents/github/PyFa-tool/tests/data/ICMSHA...
#     projection:   +proj=lcc +lat_1=49 +lat_2=49 +lon_0=9.9 +R=6371229
#     nx:           251
#     ny:           251
#     dx:           25000
#     ...           ...
#     ndgux:        251
#     nsmax:        134
#     nlev:         46
#     refpressure:  101325.0
#     A_list:       [0.     0.0001 0.0003 0.0007 0.0013 0.0023 0.0045 0.0051 0....
#     B_list:       [0.     0.0001 0.0003 0.0007 0.0013 0.0023 0.0045 0.0051 0....

# %% [markdown]
# ## Usefull Dataset methods
# Here is a collection of useful data methods:

# %% [markdown]
# ### Get info
# Some methods useful for extracting info

# %%
print(f' fieldnames: {full_data.get_fieldnames()}')
print(f' basedate: {full_data.get_basedate()}')
print(f' leadtime: {full_data.get_leadtime()}')
# Out:
#  fieldnames: ['PROFTEMPERATURE', 'SURFALBEDO.VEG', 'TEMPERATURE']
#  basedate: 2022-12-01 00:00:00
#  leadtime: 30 days 12:00:00

# %% [markdown]
# ### Plot and reproject
# A geospatial plot method is available to plot 2d fields or a 2d crosssection of a 3d field. If the coordinates are in lat-lon, the land and sea borders can be drawn as well.

# %%
#make a plot at the model CRS (without reprojectiong)
full_data.plot(variable='TEMPERATURE', level=21)
# Out:
# <GeoAxes: title={'center': 'TEMPERATURE at 2022-12-31 12:00:00 (UTC, LT=30 days 12:00:00)'}, xlabel='longitude [degrees_east]', ylabel='latitude [degrees_north]'>

# %%
#First we reproject to latlon using the epsg code
full_data.reproject(target_epsg='EPSG:4326')

# Then we plot a field
full_data.plot(variable='PROFTEMPERATURE',
               level=None, #only required for 3d fields
               title=None, # 
               grid=False,
               land=None, #if in latlon, then this will we set to True by default and the boarders are drawn
               coastline=None, #equivalent to land
               contour=False, #Set to true if you want a contour plot
               contour_levels=10, #only used if contour
               # **kwargs,
               cmap = 'viridis', #kwargs passed to xarray.plot()
              )
# Out:
# Reprojecting dataset to EPSG:4326.
# <GeoAxes: title={'center': 'PROFTEMPERATURE at 2022-12-31 12:00:00 (UTC, LT=30 days 12:00:00)'}, xlabel='longitude [degrees_east]', ylabel='latitude [degrees_north]'>

# %% [markdown]
# ## Saving an opening netCDF
# We can save the FA data to a netCDF file format, which can be opened or used by many other programs.

# %%
import os
outputfolder = os.getcwd() #specify an output folder

full_data.save_nc(outputfolder = outputfolder,
                  filename='some_fields_of_the_demo_fa_file.nc',
                  overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       1 import os
#       2 outputfolder = os.getcwd() #specify an output folder
# ----> 4 full_data.save_nc(outputfolder = outputfolder,
#       5                   filename='some_fields_of_the_demo_fa_file.nc',
#       6                   overwrite=True)
#
# File ~/Documents/github/PyFa-tool/pyfa_tool/dataset.py:615, in FaDataset.save_nc(self, outputfolder, filename, overwrite, **kwargs)
#     613 saveds = self.ds
#     614 #serialise special attributes
# --> 615 saveds.attrs['basedate'] = datetime.strftime(saveds.attrs['basedate'],
#     616                                              '%Y-%m-%d %H:%M:%S' )
#     617 saveds.attrs['validate'] = datetime.strftime(saveds.attrs['validate'],
#     618                                              '%Y-%m-%d %H:%M:%S' )
#     619 saveds.attrs['leadtime'] = saveds.attrs['leadtime'].seconds
#
# KeyError: 'basedate'

# %% [markdown]
# To read a netcdf file, you can use xarray or use the pyfa method (wrapper on xarray.read_netDF)

# %%
path_to_nc = os.path.join(outputfolder,'some_fields_of_the_demo_fa_file.nc')
new_dataset = pyfa.FaDataset()
new_dataset.read_nc(path_to_nc)
